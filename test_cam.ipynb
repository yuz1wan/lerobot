# %%
from lerobot.common.robot_devices.motors.dynamixel import DynamixelMotorsBus

leader_port = "/dev/tty.usbmodem575E0031751"
follower_port = "/dev/tty.usbmodem575E0032081"

leader_arm = DynamixelMotorsBus(
    port=leader_port,
    motors={
        # name: (index, model)
        "shoulder_pan": (1, "xl330-m077"),
        "shoulder_lift": (2, "xl330-m077"),
        "elbow_flex": (3, "xl330-m077"),
        "wrist_flex": (4, "xl330-m077"),
        "wrist_roll": (5, "xl330-m077"),
        "gripper": (6, "xl330-m077"),
    },
)

follower_arm = DynamixelMotorsBus(
    port=follower_port,
    motors={
        # name: (index, model)
        "shoulder_pan": (1, "xl430-w250"),
        "shoulder_lift": (2, "xl430-w250"),
        "elbow_flex": (3, "xl330-m288"),
        "wrist_flex": (4, "xl330-m288"),
        "wrist_roll": (5, "xl330-m288"),
        "gripper": (6, "xl330-m288"),
    },
)

# %%
from lerobot.common.robot_devices.cameras.opencv import OpenCVCamera
from lerobot.common.robot_devices.robots.manipulator import ManipulatorRobot


robot = ManipulatorRobot(
    leader_arms={"main": leader_arm},
    follower_arms={"main": follower_arm},
    calibration_dir=".cache/calibration/koch",
    cameras={
        "laptop": OpenCVCamera(0, fps=30, width=640, height=480),
        "phone": OpenCVCamera(1, fps=30, width=640, height=480),
    },
)
robot.connect()
# Out:
# Connecting main follower arm.
#
# Try running `python lerobot/scripts/find_motors_bus_port.py` to make sure you are using the correct port.
# Traceback (most recent call last):
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialposix.py", line 322, in open
#     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbmodem575E0032081'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/wangxiaoyi/Documents/Coding/lerobot/lerobot/common/robot_devices/motors/dynamixel.py", line 337, in connect
#     if not self.port_handler.openPort():
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py", line 44, in openPort
#     return self.setBaudRate(self.baudrate)
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py", line 68, in setBaudRate
#     return self.setupPort(baud)
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py", line 114, in setupPort
#     self.ser = serial.Serial(
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialutil.py", line 244, in __init__
#     self.open()
#   File "/Users/wangxiaoyi/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialposix.py", line 325, in open
#     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
# serial.serialutil.SerialException: [Errno 2] could not open port /dev/tty.usbmodem575E0032081: [Errno 2] No such file or directory: '/dev/tty.usbmodem575E0032081'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialposix.py:322, in Serial.open(self)
#     321 try:
# --> 322     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323 except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbmodem575E0032081'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# Cell In[9], line 14
#       2 from lerobot.common.robot_devices.robots.manipulator import ManipulatorRobot
#       5 robot = ManipulatorRobot(
#       6     leader_arms={"main": leader_arm},
#       7     follower_arms={"main": follower_arm},
#    (...)
#      12     },
#      13 )
# ---> 14 robot.connect()
#
# File ~/Documents/Coding/lerobot/lerobot/common/robot_devices/robots/manipulator.py:299, in ManipulatorRobot.connect(self)
#     297 for name in self.follower_arms:
#     298     print(f"Connecting {name} follower arm.")
# --> 299     self.follower_arms[name].connect()
#     300 for name in self.leader_arms:
#     301     print(f"Connecting {name} leader arm.")
#
# File ~/Documents/Coding/lerobot/lerobot/common/robot_devices/motors/dynamixel.py:337, in DynamixelMotorsBus.connect(self)
#     334 self.packet_handler = dxl.PacketHandler(PROTOCOL_VERSION)
#     336 try:
# --> 337     if not self.port_handler.openPort():
#     338         raise OSError(f"Failed to open port '{self.port}'.")
#     339 except Exception:
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py:44, in PortHandler.openPort(self)
#      43 def openPort(self):
# ---> 44     return self.setBaudRate(self.baudrate)
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py:68, in PortHandler.setBaudRate(self, baudrate)
#      66 else:
#      67     self.baudrate = baudrate
# ---> 68     return self.setupPort(baud)
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/dynamixel_sdk/port_handler.py:114, in PortHandler.setupPort(self, cflag_baud)
#     111 if self.is_open:
#     112     self.closePort()
# --> 114 self.ser = serial.Serial(
#     115     port=self.port_name,
#     116     baudrate=self.baudrate,
#     117     # parity = serial.PARITY_ODD,
#     118     # stopbits = serial.STOPBITS_TWO,
#     119     bytesize=serial.EIGHTBITS,
#     120     timeout=0
#     121 )
#     123 self.is_open = True
#     125 self.ser.reset_input_buffer()
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File ~/miniconda3/envs/lerobot/lib/python3.10/site-packages/serial/serialposix.py:325, in Serial.open(self)
#     323 except OSError as msg:
#     324     self.fd = None
# --> 325     raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326 #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     328 self.pipe_abort_read_r, self.pipe_abort_read_w = None, None
#
# SerialException: [Errno 2] could not open port /dev/tty.usbmodem575E0032081: [Errno 2] No such file or directory: '/dev/tty.usbmodem575E0032081'

# %%
observation, action = robot.teleop_step(record_data=True)
print(observation["observation.images.laptop"].shape)
print(observation["observation.images.phone"].shape)
print(observation["observation.images.laptop"].min().item())
print(observation["observation.images.laptop"].max().item())
